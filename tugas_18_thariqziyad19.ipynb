# %% [markdown]
# # Soal 1: Pemahaman Teori
# Jelaskan perbedaan antara Univariate, Bivariate dan Multivariate Analysis

# %% [markdown]
# Jawaban:

# %% [markdown]
# Univariate analysis hanya menganalisa satu variabel, Bivariate menganalisa dua variabel, dan Multivariate menganalisa lebih dari dua variabel
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 2. Persiapan Data
#
# *   Hapus nilai missing dalam rows dataset menggunakan atribut.dropna()
#
# *   Lakukan grouping data berdasarkan kolom 'species' dengan menggunakan agregasi mean()

# %%
#code here

df.dropna(inplace=True)
df_species = df.groupby('species').mean()
df_species
# Out:
# C:\Users\Ziyad\AppData\Local\Temp\ipykernel_8664\2871606321.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_species = df.groupby('species').mean()
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.823973      18.347260         190.102740  3706.164384
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.568067      14.996639         217.235294  5092.436975

# %% [markdown]
# Expected output:
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1OnuXmscVRqduqT_TYI1vB291rpXM4D_1)

# %% [markdown]
# # Soal 3. Univariate Analysis
# Buatlah sebuah analisa univariate dengan menggunakan perintah seperti berikut:
#
# *   Buatlah sebuah Pie plot dari dataset hasil grouping untuk kolom flipper_length_mm seperti expected output berikut:
# *   Buatlah sebuah plot histogram dari dataset awal (sebelum grouping) untuk kolom body_mass_g
# *   Jelaskan insight yang diperoleh dari ke dua grafik tersebut.

# %%
#code here
print('Pie Chart')

plt.figure(figsize=(10,6))
plt.pie(df_species['flipper_length_mm'],labels=df_species.index,autopct='%.2f%%')
plt.title('flipper length (mm)')
plt.show()
# Out:
# Pie Chart

# %%
print('Histogram')

plt.figure(figsize=(10,6))
plt.hist(df['body_mass_g'])
plt.title('body mass (g)')
plt.xlabel('body mass (g)')
plt.ylabel('count')
plt.show()
# Out:
# Histogram

# %% [markdown]
# Expected Output:
#
#
# Pie Chart
#
# ![](https://drive.google.com/uc?id=11H6X7xpEeodPWD56tHBhV4sLrJ-6B-Bd)
#
# Histogram
#
# ![](https://drive.google.com/uc?id=1A_twS7BbQhkGvUz7zAWgye7q3ZRTQkhi)

# %% [markdown]
# Analisa:

# %% [markdown]
# Panjang flipper untuk ketiga spesies memiliki rata-rata yang tidak terlalu jauh satu sama lain, meski spesies *gentoo* memiliki rata-rata paling tinggi sebesar 4-6 persen lebih panjang dari dua spesies lainnya.
#
# ---
#
# Modus massa semua pinguin dalam data adalah sekitar 3,5 kg, yang dimiliki oleh hampir 70 pinguin individu dalam data yang dianalisa.
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 4. Bivariate Analysis
#
#
#
# *   Buatlah sebuah grafik catplot menggunakan seaborn dengan x='sex', y='bill_length_mm' dan kind 'bar' seperti expected output di bawah
# *   Buatlah sebuah grafik scatter plot menggunakan seaborn dengan x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm' seperti expected dibawah
# *   Jelaskan insight yang diperoleh dari hasil analisa bivariate tersebut

# %%
#code here
print('Catplot')

sns.catplot(data=df,x='sex', y='bill_length_mm',kind='bar')
plt.show()
# Out:
# Catplot

# %%
print('Scatter plot')

plt.figure(figsize=(12,8))
sns.scatterplot(data=df,x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm')
plt.show()
# Out:
# Scatter plot

# %% [markdown]
# Expected Output:
#
# Catplot
#
# ![](https://drive.google.com/uc?id=1imCbGD9cWqXUjd33tAh6D0OH20vVpWea)
#
# Scatter plot
#
# ![](https://drive.google.com/uc?id=1_k734IpRYq6Q1wF57hwzSEjnVd2Sii2Z)

# %% [markdown]
# Analisa:

# %% [markdown]
# Untuk semua jenis spesies pinguin, pinguin jantan memiliki rata_rata panjang paruh yang lebih besar dari pada pinguin betina.
#
# ---
# Secara umum massa badan pinguin dan panjang *flipper*nya memiliki korelasi positif, dimana semakin panjang *flipper*, maka semakin berat massa pinguin tersebut. Panjang paruh juga memiliki korelasi positif dengan berat badan pinguin, meskipun korelasinya lebih lemah.
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 5. Multivariate Analisis
#
# *   Dengan menggunakan seaborn, buatlah sebuah pairplot keseluruhan data feature pada dataset (df) dengan argumen kind='bar', seperti expected di bawah:
# *   Jelaskan hasil analisa dari multivariate yang dihasilkan

# %%
#code here

sns.pairplot(df,kind='scatter') #kind='bar' menghasilkan grafik kosong kecuali di diagonal
plt.show()

# %% [markdown]
# Expected output:
#
# Pair plot
#
# ![](https://drive.google.com/uc?id=1td8WAZLJEW5BPTq-wEJyZ4soRNNLXfqX)

# %% [markdown]
# Analisa:

# %% [markdown]
# Seperti yang sudah disimpulkan di pertanyaan sebelum ini, berat badan pinguin memiliki korelasi positif terhadap panjang paruh dan panjang *flipper* pinguin. Panjang paruh juga memiliki korelasi positif terhadap panjang *flipper*. Tebal paruh tidak terlihat memiliki korelasi yang jelas terhadap variabel-variabel lain, akan tetapi data tebal paruh dengan panjang *flipper* serta data tebal paruh dengan berat badan yang tervisualisasi seolah menjadi dua set. Untuk analisa lebih lanjut saya membuat *scatter plot* dari dua set variabel tersebut dengan membedakan jenis kelamin dan spesies masing-masing pinguin:

# %%
fig, ax = plt.subplots(2,2,sharex=True,figsize=(10,8))

c_sex = {'Male':'Cyan','Female':'Pink'}
c_spc = {'Adelie':'Red', 'Chinstrap':'Green', 'Gentoo':'Blue'}

ax[0][0].scatter('bill_depth_mm','flipper_length_mm',data=df,c=[c_sex[i] for i in df.sex])
ax[0][0].set_ylabel('flipper_length_mm')
ax[0][1].scatter('bill_depth_mm','flipper_length_mm',data=df,c=[c_spc[i] for i in df.species])
ax[1][0].scatter('bill_depth_mm','body_mass_g',data=df,c=[c_sex[i] for i in df.sex])
ax[1][0].set_ylabel('body_mass_g')
ax[1][1].scatter('bill_depth_mm','body_mass_g',data=df,c=[c_spc[i] for i in df.species])
plt.show()

# %% [markdown]
# Bisa kita lihat bahwa jenis kelamin tidak menambah korelasi antara variabel. Akan tetapi kita bisa lihat bahwa untuk masing masing spesies, terutama untuk spesies *gentoo*, tebal paruh memiliki korelasi positif terhadap panjang *flipper* dan berat badan.
